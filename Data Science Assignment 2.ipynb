# %%
import numpy as np

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
dict1={"Roll_No":[11,12,13,14,15],"Name":["Ajay","raj","Shree","Abhi","Pranav"],"Maths_marks":[99,88,80,90,np.nan],"English_marks":[99,99,98,np.nan,89],"Science_marks":[88,95,np.nan,78,90],"History_marks":[98,np.nan,78,90,88],"Geography_marks":[np.nan,80,88,98,90]}
df=pd.DataFrame(dict1)
df
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0       11    Ajay         99.0           99.0           88.0           98.0
# 1       12     raj         88.0           99.0           95.0            NaN
# 2       13   Shree         80.0           98.0            NaN           78.0
# 3       14    Abhi         90.0            NaN           78.0           90.0
# 4       15  Pranav          NaN           89.0           90.0           88.0
#
#    Geography_marks
# 0              NaN
# 1             80.0
# 2             88.0
# 3             98.0
# 4             90.0

# %%
df.isnull().sum()
# Out:
# Roll_No            0
# Name               0
# Maths_marks        1
# English_marks      1
# Science_marks      1
# History_marks      1
# Geography_marks    1
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Roll_No          5 non-null      int64
#  1   Name             5 non-null      object
#  2   Maths_marks      4 non-null      float64
#  3   English_marks    4 non-null      float64
#  4   Science_marks    4 non-null      float64
#  5   History_marks    4 non-null      float64
#  6   Geography_marks  4 non-null      float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 412.0+ bytes

# %%
bool_series = pd.notnull(df)
bool_series
# Out:
#    Roll_No  Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0     True  True         True           True           True           True
# 1     True  True         True           True           True          False
# 2     True  True         True           True          False           True
# 3     True  True         True          False           True           True
# 4     True  True        False           True           True           True
#
#    Geography_marks
# 0            False
# 1             True
# 2             True
# 3             True
# 4             True

# %%
dict1={"Roll_No":[11,12,13,14,15],"Name":["Ajay","raj","Shree","Abhi","Pranav"],"Maths_marks":[99,88,80,90,np.nan],"English_marks":[99,99,98,np.nan,89],"Science_marks":[88,95,np.nan,78,90],"History_marks":[98,np.nan,78,90,88],"Geography_marks":[np.nan,80,88,98,90]}

# %%
# filling missing value using fillna() 
df.fillna(92,inplace=True)
df
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0       11    Ajay         99.0           99.0           88.0           98.0
# 1       12     raj         88.0           99.0           95.0           92.0
# 2       13   Shree         80.0           98.0           92.0           78.0
# 3       14    Abhi         90.0           92.0           78.0           90.0
# 4       15  Pranav         92.0           89.0           90.0           88.0
#
#    Geography_marks
# 0             92.0
# 1             80.0
# 2             88.0
# 3             98.0
# 4             90.0

# %%
dict1={"Roll_No":[1,2,3,4,5],"Name":["Amol","Dipak","Shreya","Krisha","Pooja"],"Maths_marks":[60,70,80,90,np.nan],"English_marks":[70,80,90,np.nan,60],"Science_marks":[80,90,np.nan,60,70],"History_marks":[90,np.nan,60,70,80],"Geography_marks":[np.nan,60,70,80,90]}

# %%
df.fillna(method ='pad')
# Out:
# C:\Users\vedsh\AppData\Local\Temp\ipykernel_19404\3046802722.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method ='pad')
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0       11    Ajay         99.0           99.0           88.0           98.0
# 1       12     raj         88.0           99.0           95.0           92.0
# 2       13   Shree         80.0           98.0           92.0           78.0
# 3       14    Abhi         90.0           92.0           78.0           90.0
# 4       15  Pranav         92.0           89.0           90.0           88.0
#
#    Geography_marks
# 0             92.0
# 1             80.0
# 2             88.0
# 3             98.0
# 4             90.0

# %%
# filling a missing value with
# next ones
df.fillna(method ='bfill')
# Out:
# C:\Users\vedsh\AppData\Local\Temp\ipykernel_19404\4267371381.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method ='bfill')
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0       11    Ajay         99.0           99.0           88.0           98.0
# 1       12     raj         88.0           99.0           95.0           92.0
# 2       13   Shree         80.0           98.0           92.0           78.0
# 3       14    Abhi         90.0           92.0           78.0           90.0
# 4       15  Pranav         92.0           89.0           90.0           88.0
#
#    Geography_marks
# 0             92.0
# 1             80.0
# 2             88.0
# 3             98.0
# 4             90.0

# %%
dict1={"Roll_No":[11,12,13,14,15],"Name":["Ajay","raj","Shree","Abhi","Pranav"],"Maths_marks":[99,88,80,90,np.nan],"English_marks":[99,99,98,np.nan,89],"Science_marks":[88,95,np.nan,78,90],"History_marks":[98,np.nan,78,90,88],"Geography_marks":[np.nan,80,88,98,90]}
df=pd.DataFrame(dict1)
df
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0       11    Ajay         99.0           99.0           88.0           98.0
# 1       12     raj         88.0           99.0           95.0            NaN
# 2       13   Shree         80.0           98.0            NaN           78.0
# 3       14    Abhi         90.0            NaN           78.0           90.0
# 4       15  Pranav          NaN           89.0           90.0           88.0
#
#    Geography_marks
# 0              NaN
# 1             80.0
# 2             88.0
# 3             98.0
# 4             90.0

# %%
df
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0       11    Ajay         99.0           99.0           88.0           98.0
# 1       12     raj         88.0           99.0           95.0            NaN
# 2       13   Shree         80.0           98.0            NaN           78.0
# 3       14    Abhi         90.0            NaN           78.0           90.0
# 4       15  Pranav          NaN           89.0           90.0           88.0
#
#    Geography_marks
# 0              NaN
# 1             80.0
# 2             88.0
# 3             98.0
# 4             90.0

# %%
# filling a null values using fillna()
df["Maths_marks"].fillna(99, inplace = True)
df["English_marks"].fillna(99, inplace = True)
df["Science_marks"].fillna(88, inplace = True)
df["History_marks"].fillna(98, inplace = True)
df["Geography_marks"].fillna(92, inplace = True)
# Out:
# C:\Users\vedsh\AppData\Local\Temp\ipykernel_19404\1935693632.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Maths_marks"].fillna(99, inplace = True)
# C:\Users\vedsh\AppData\Local\Temp\ipykernel_19404\1935693632.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
df
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0       11    Ajay         99.0           99.0           88.0           98.0
# 1       12     raj         88.0           99.0           95.0           98.0
# 2       13   Shree         80.0           98.0           88.0           78.0
# 3       14    Abhi         90.0           99.0           78.0           90.0
# 4       15  Pranav         99.0           89.0           90.0           88.0
#
#    Geography_marks
# 0             92.0
# 1             80.0
# 2             88.0
# 3             98.0
# 4             90.0

# %%
dict1={"Roll_No":[11,12,13,14,15],"Name":["Ajay","raj","Shree","Abhi","Pranav"],"Maths_marks":[99,88,80,90,np.nan],"English_marks":[99,99,98,np.nan,89],"Science_marks":[88,95,np.nan,78,90],"History_marks":[98,np.nan,78,90,88],"Geography_marks":[np.nan,80,88,98,90]}
df=pd.DataFrame(dict1)
df
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0       11    Ajay         99.0           99.0           88.0           98.0
# 1       12     raj         88.0           99.0           95.0            NaN
# 2       13   Shree         80.0           98.0            NaN           78.0
# 3       14    Abhi         90.0            NaN           78.0           90.0
# 4       15  Pranav          NaN           89.0           90.0           88.0
#
#    Geography_marks
# 0              NaN
# 1             80.0
# 2             88.0
# 3             98.0
# 4             90.0

# %%
# filling a null values using fillna()
df["Maths_marks"].fillna(int(df["Maths_marks"].mean()), inplace=True)
# Out:
# C:\Users\vedsh\AppData\Local\Temp\ipykernel_19404\1690215622.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Maths_marks"].fillna(int(df["Maths_marks"].mean()), inplace=True)

# %%
df
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0       11    Ajay         99.0           99.0           88.0           98.0
# 1       12     raj         88.0           99.0           95.0            NaN
# 2       13   Shree         80.0           98.0            NaN           78.0
# 3       14    Abhi         90.0            NaN           78.0           90.0
# 4       15  Pranav         89.0           89.0           90.0           88.0
#
#    Geography_marks
# 0              NaN
# 1             80.0
# 2             88.0
# 3             98.0
# 4             90.0

# %%
dict1={"Roll_No":[11,12,13,14,15],"Name":["Ajay","raj","Shree","Abhi","Pranav"],"Maths_marks":[99,88,80,90,np.nan],"English_marks":[99,99,98,np.nan,89],"Science_marks":[88,95,np.nan,78,90],"History_marks":[98,np.nan,78,90,88],"Geography_marks":[np.nan,80,88,98,90]}
df=pd.DataFrame(dict1)
df
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0       11    Ajay         99.0           99.0           88.0           98.0
# 1       12     raj         88.0           99.0           95.0            NaN
# 2       13   Shree         80.0           98.0            NaN           78.0
# 3       14    Abhi         90.0            NaN           78.0           90.0
# 4       15  Pranav          NaN           89.0           90.0           88.0
#
#    Geography_marks
# 0              NaN
# 1             80.0
# 2             88.0
# 3             98.0
# 4             90.0

# %%
# will replace  Nan value in dataframe with value 88 
df.replace(to_replace = np.nan, value = 88)
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0       11    Ajay         99.0           99.0           88.0           98.0
# 1       12     raj         88.0           99.0           95.0           88.0
# 2       13   Shree         80.0           98.0           88.0           78.0
# 3       14    Abhi         90.0           88.0           78.0           90.0
# 4       15  Pranav         88.0           89.0           90.0           88.0
#
#    Geography_marks
# 0             88.0
# 1             80.0
# 2             88.0
# 3             98.0
# 4             90.0

# %%
dict1={"Roll_No":[11,12,13,14,15],"Name":["Ajay","raj","Shree","Abhi","Pranav"],"Maths_marks":[99,88,80,90,np.nan],"English_marks":[99,99,98,np.nan,89],"Science_marks":[88,95,np.nan,78,90],"History_marks":[98,np.nan,78,90,88],"Geography_marks":[np.nan,80,88,98,90]}
df=pd.DataFrame(dict1)
df
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0       11    Ajay         99.0           99.0           88.0           98.0
# 1       12     raj         88.0           99.0           95.0            NaN
# 2       13   Shree         80.0           98.0            NaN           78.0
# 3       14    Abhi         90.0            NaN           78.0           90.0
# 4       15  Pranav          NaN           89.0           90.0           88.0
#
#    Geography_marks
# 0              NaN
# 1             80.0
# 2             88.0
# 3             98.0
# 4             90.0

# %%
# to interpolate the missing values
df.interpolate(method ='linear', limit_direction ='forward')
#c=(a+b)/2
# Out:
# C:\Users\vedsh\AppData\Local\Temp\ipykernel_19404\3847532912.py:2: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   df.interpolate(method ='linear', limit_direction ='forward')
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0       11    Ajay         99.0           99.0           88.0           98.0
# 1       12     raj         88.0           99.0           95.0           88.0
# 2       13   Shree         80.0           98.0           86.5           78.0
# 3       14    Abhi         90.0           93.5           78.0           90.0
# 4       15  Pranav         90.0           89.0           90.0           88.0
#
#    Geography_marks
# 0              NaN
# 1             80.0
# 2             88.0
# 3             98.0
# 4             90.0

# %%
dict1={"Roll_No":[11,12,13,14,15],"Name":["Ajay","raj","Shree","Abhi","Pranav"],"Maths_marks":[99,88,80,90,np.nan],"English_marks":[99,99,98,np.nan,89],"Science_marks":[88,95,np.nan,78,90],"History_marks":[98,np.nan,78,90,88],"Geography_marks":[np.nan,80,88,98,90]}
df=pd.DataFrame(dict1)
df
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0       11    Ajay         99.0           99.0           88.0           98.0
# 1       12     raj         88.0           99.0           95.0            NaN
# 2       13   Shree         80.0           98.0            NaN           78.0
# 3       14    Abhi         90.0            NaN           78.0           90.0
# 4       15  Pranav          NaN           89.0           90.0           88.0
#
#    Geography_marks
# 0              NaN
# 1             80.0
# 2             88.0
# 3             98.0
# 4             90.0

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Roll_No, Name, Maths_marks, English_marks, Science_marks, History_marks, Geography_marks]
# Index: []

# %%
dict1={"Roll_No":[11,12,13,14,15],"Name":["Ajay","raj","Shree","Abhi","Pranav"],"Maths_marks":[99,88,80,90,np.nan],"English_marks":[99,99,98,np.nan,89],"Science_marks":[88,95,np.nan,78,90],"History_marks":[98,np.nan,78,90,88],"Geography_marks":[np.nan,80,88,98,90]}
df=pd.DataFrame(dict1)
df
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0       11    Ajay         99.0           99.0           88.0           98.0
# 1       12     raj         88.0           99.0           95.0            NaN
# 2       13   Shree         80.0           98.0            NaN           78.0
# 3       14    Abhi         90.0            NaN           78.0           90.0
# 4       15  Pranav          NaN           89.0           90.0           88.0
#
#    Geography_marks
# 0              NaN
# 1             80.0
# 2             88.0
# 3             98.0
# 4             90.0

# %%
# using dropna() function     
df.dropna(how = 'all',inplace=True)

# %%
df
# Out:
#    Roll_No    Name  Maths_marks  English_marks  Science_marks  History_marks  \
# 0       11    Ajay         99.0           99.0           88.0           98.0
# 1       12     raj         88.0           99.0           95.0            NaN
# 2       13   Shree         80.0           98.0            NaN           78.0
# 3       14    Abhi         90.0            NaN           78.0           90.0
# 4       15  Pranav          NaN           89.0           90.0           88.0
#
#    Geography_marks
# 0              NaN
# 1             80.0
# 2             88.0
# 3             98.0
# 4             90.0

# %%
# making new data frame with dropped NA values
df2 = df.dropna(axis = 0, how ='any')
df2
# Out:
# Empty DataFrame
# Columns: [Roll_No, Name, Maths_marks, English_marks, Science_marks, History_marks, Geography_marks]
# Index: []

# %%
df=pd.read_csv("HousingData.csv")

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# #  1.Visualization

# %%
 #Box Plot
import seaborn as sns
sns.boxplot(df['DIS'])
# Out:
# <Axes: ylabel='DIS'>

# %%
# Position of the Outlier
print(np.where(df['DIS']>10))
# Out:
# (array([351, 352, 353, 354, 355]),)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %% [markdown]
# # 2. Using Scatter Plot

# %%
# Scatter plot
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(df['INDUS'], df['TAX'])
 
# x-axis label
ax.set_xlabel('(Proportion non-retail business acres)/(town)')
 
# y-axis label
ax.set_ylabel('(Full-value property-tax rate)/( $10,000)')
plt.show()

# %%
# Position of the Outlier
print(np.where((df['INDUS']>20) & (df['TAX']>600)))
# Out:
# (array([488, 489, 490, 491, 492]),)

# %% [markdown]
# # 2. Z score

# %%
# Z score
from scipy import stats
import numpy as np
 
z = np.abs(stats.zscore(df['DIS']))
print(z)
# Out:
# [1.40213603e-01 5.57159875e-01 5.57159875e-01 1.07773662e+00
#  1.07773662e+00 1.07773662e+00 8.39243922e-01 1.02463789e+00
#  1.08719646e+00 1.32963473e+00 1.21297914e+00 1.15593484e+00
#  7.87143464e-01 4.33754047e-01 3.17003386e-01 3.34449434e-01
#  3.34449434e-01 2.20028082e-01 6.92761271e-04 6.92761271e-04
#  1.35827806e-03 1.03277421e-01 8.64493539e-02 1.42685523e-01
#  2.87387889e-01 3.13533191e-01 4.21632134e-01 3.12962749e-01
#  3.13580728e-01 2.11043605e-01 2.08191390e-01 1.80619980e-01
#  9.26766896e-02 3.72817172e-03 1.67532861e-02 2.06663257e-01
#  1.98296760e-01 6.61510917e-02 2.48415135e-02 7.63470081e-01
#  7.63470081e-01 9.15493132e-01 9.15493132e-01 9.15493132e-01
#  9.15493132e-01 6.20526581e-01 6.20526581e-01 9.00519004e-01
#  9.86370670e-01 1.08985853e+00 1.43545190e+00 1.43545190e+00
#  1.43545190e+00 1.43545190e+00 1.67551331e+00 2.33004908e+00
#  2.56345533e+00 2.15330683e+00 1.91086857e+00 1.49121270e+00
# ...

# %%
threshold = 2
 
# Position of the outlier
print(np.where(z > 2))
# Out:
# (array([ 55,  56,  57,  64, 246, 247, 252, 253, 254, 255, 286, 345, 346,
#        347, 348, 349, 350, 351, 352, 353, 354, 355]),)

# %% [markdown]
# # 3 IQR (Inter Quartile Range)

# %%
# IQR
Q1 = np.percentile(df['DIS'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(df['DIS'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1

# %%
# Above Upper bound
upper = df['DIS'] >= (Q3+1.5*IQR)
 
print("Upper bound:",upper)
print(np.where(upper))
 
# Below Lower bound
lower = df['DIS'] <= (Q1-1.5*IQR)
print("Lower bound:", lower)
print(np.where(lower))
# Out:
# Upper bound: 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 501    False
# 502    False
# 503    False
# 504    False
# 505    False
# Name: DIS, Length: 506, dtype: bool
# (array([351, 352, 353, 354, 355]),)
# Lower bound: 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 501    False
# 502    False
# 503    False
# 504    False
# 505    False
# Name: DIS, Length: 506, dtype: bool
# (array([], dtype=int64),)

# %% [markdown]
# #  Removing Outliers

# %%
# Importing
import sklearn
#from sklearn.datasets import load_boston
import pandas as pd

# Load the dataset
#bos_hou = load_boston()
df_boston=pd.read_csv('HousingData.csv')
''' Detection '''
# IQR
Q1 = np.percentile(df_boston['DIS'], 25,
				interpolation = 'midpoint')

Q3 = np.percentile(df_boston['DIS'], 75,
				interpolation = 'midpoint')
IQR = Q3 - Q1

print("Old Shape: ", df_boston.shape)

# Upper bound
upper = np.where(df_boston['DIS'] >= (Q3+1.5*IQR))
# Lower bound
lower = np.where(df_boston['DIS'] <= (Q1-1.5*IQR))

''' Removing the Outliers '''
df_boston.drop(upper[0], inplace = True)
df_boston.drop(lower[0], inplace = True)

print("New Shape: ", df_boston.shape)
# Out:
# Old Shape:  (506, 14)
# New Shape:  (501, 14)

# %% [markdown]
# # 3.Data Transformation

# %%
# importing pandas as pd
import pandas as pd

# Creating the DataFrame
df = pd.DataFrame({"A":[12, 4, 5, None, 1],
				"B":[7, 2, 54, 3, None],
				"C":[20, 16, 11, 3, 8],
				"D":[14, 3, None, 2, 6]})

# Create the index
index_ = ['Row_1', 'Row_2', 'Row_3', 'Row_4', 'Row_5']

# Set the index
df.index = index_

# Print the DataFrame
print(df)
# Out:
#           A     B   C     D
# Row_1  12.0   7.0  20  14.0
# Row_2   4.0   2.0  16   3.0
# Row_3   5.0  54.0  11   NaN
# Row_4   NaN   3.0   3   2.0
# Row_5   1.0   NaN   8   6.0

# %%
# pass a list of functions
result = df.transform(func = ['sqrt', 'exp'])
result
# Print the result
#print(result)
# Out:
#               A                        B                       C  \
#            sqrt            exp      sqrt           exp      sqrt
# Row_1  3.464102  162754.791419  2.645751  1.096633e+03  4.472136
# Row_2  2.000000      54.598150  1.414214  7.389056e+00  4.000000
# Row_3  2.236068     148.413159  7.348469  2.830753e+23  3.316625
# Row_4       NaN            NaN  1.732051  2.008554e+01  1.732051
# Row_5  1.000000       2.718282       NaN           NaN  2.828427
#
#                             D
#                 exp      sqrt           exp
# Row_1  4.851652e+08  3.741657  1.202604e+06
# Row_2  8.886111e+06  1.732051  2.008554e+01
# Row_3  5.987414e+04       NaN           NaN
# Row_4  2.008554e+01  1.414214  7.389056e+00
# Row_5  2.980958e+03  2.449490  4.034288e+02

# %% [markdown]
# #  Scaling

# %% [markdown]
# # Method :Using numpy and pandas

# %%
import seaborn as sns
import pandas as pd
import numpy as np

data = sns.load_dataset('iris')
print('Original Dataset')
data.head()
# Out:
# Original Dataset
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Min-Max Normalization
df = data.drop('species', axis=1)
df_norm = (df-df.min())/(df.max()-df.min())
df_norm = pd.concat((df_norm, data.species), axis=1)

print("Scaled Dataset Using Pandas")
df_norm.head()
# Out:
# Scaled Dataset Using Pandas
#    sepal_length  sepal_width  petal_length  petal_width species
# 0      0.222222     0.625000      0.067797     0.041667  setosa
# 1      0.166667     0.416667      0.067797     0.041667  setosa
# 2      0.111111     0.500000      0.050847     0.041667  setosa
# 3      0.083333     0.458333      0.084746     0.041667  setosa
# 4      0.194444     0.666667      0.067797     0.041667  setosa

# %%
# skewness along the index axis
df_norm.skew(axis=0, skipna=True, numeric_only=True)
# Out:
# sepal_length    0.314911
# sepal_width     0.318966
# petal_length   -0.274884
# petal_width    -0.102967
# dtype: float64

# %%
# find skewness in each row
df.skew(axis = 1, skipna = True)
# Out:
# 0      0.189328
# 1      0.404389
# 2      0.208782
# 3      0.120130
# 4      0.090753
#          ...
# 145    0.351514
# 146    0.256478
# 147    0.134795
# 148   -0.146244
# 149   -0.185387
# Length: 150, dtype: float64

# %% [markdown]
# # Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics
  

  
# Calculating mean and standard deviation
mean = statistics.mean(df_norm["sepal_length"])
sd = statistics.stdev(df_norm["sepal_length"])
  
plt.plot(df_norm["sepal_length"], norm.pdf(df_norm["sepal_length"], mean, sd))
plt.show()
print(mean)
print(sd)
# Out:
# 0.4287037037037037
# 0.2300183688827397

# %%
# Calculating mean and standard deviation
mean = statistics.mean(df_norm["petal_width"])
sd = statistics.stdev(df_norm["petal_width"])
  
plt.plot(df_norm["petal_width"], norm.pdf(df_norm["petal_width"], mean, sd))
plt.show()
print(mean)
print(sd)
# Out:
# 0.45805555555555555
# 0.31759902873347773

# %%
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import pandas as pd

data = sns.load_dataset('iris')
print('Original Dataset')
data.head()

scaler = MinMaxScaler()

df_scaled = scaler.fit_transform(df.to_numpy())
df_scaled = pd.DataFrame(df_scaled, columns=[
'sepal_length', 'sepal_width', 'petal_length', 'petal_width'])

print("Scaled Dataset Using MinMaxScaler")
df_scaled.head()
# Out:
# Original Dataset
# Scaled Dataset Using MinMaxScaler
#    sepal_length  sepal_width  petal_length  petal_width
# 0      0.222222     0.625000      0.067797     0.041667
# 1      0.166667     0.416667      0.067797     0.041667
# 2      0.111111     0.500000      0.050847     0.041667
# 3      0.083333     0.458333      0.084746     0.041667
# 4      0.194444     0.666667      0.067797     0.041667

# %%
# Calculating mean and standard deviation
mean = statistics.mean(df_scaled["sepal_length"])
sd = statistics.stdev(df_scaled["sepal_length"])
  
plt.plot(df_scaled["sepal_length"], norm.pdf(df_scaled["sepal_length"], mean, sd))
plt.show()
print(mean)
print(sd)
# Out:
# 0.4287037037037037
# 0.23001836888273972

# %% [markdown]
# #  Standardization

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import seaborn as sns

data = sns.load_dataset('iris')
print('Original Dataset')
data.head()
# Out:
# Original Dataset
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.drop(["species"],inplace=True,axis=1)

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
std_scaler = StandardScaler()

df_scaled = std_scaler.fit_transform(data.to_numpy())
df_scaled = pd.DataFrame(df_scaled, columns=[
'sepal_length','sepal_width','petal_length','petal_width'])

print("Scaled Dataset Using StandardScaler")
df_scaled.head()
# Out:
# Scaled Dataset Using StandardScaler
#    sepal_length  sepal_width  petal_length  petal_width
# 0     -0.900681     1.019004     -1.340227    -1.315444
# 1     -1.143017    -0.131979     -1.340227    -1.315444
# 2     -1.385353     0.328414     -1.397064    -1.315444
# 3     -1.506521     0.098217     -1.283389    -1.315444
# 4     -1.021849     1.249201     -1.340227    -1.315444
